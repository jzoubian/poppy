# %%
import poppy

from poppy.accel_math import benchmark_fft, benchmark_2d_ffts, benchmark_2d_mfts

# %%
benchmark_fft(npix=2048, iterations=20, double_precision=True)
# Out:
# Timing performance of FFT for 2048 x 2048, complex128, with 20 iterations
# Timing performance in plain numpy:
#   0.096 s
# Timing performance with FFTW:
#   0.051 s
# Timing performance with Numexpr + FFTW:
#   0.042 s
# Timing performance with Numexpr + MKL:
#   0.046 s
# Timing performance with PyTorch:
#   0.038 s
# {'numpy': 0.09569759089999934,
#  'fftw': 0.05110573199999635,
#  'numexpr': 0.041831460400044304,
#  'mkl': 0.04561566844995468,
#  'opencl': nan,
#  'cupy': nan,
#  'torch': 0.03797839559993008}

# %%
benchmark_2d_ffts(mode='base', max_pow=13, verbose=False, savefig=False)

# %% [markdown]
# Note: torch benchmark is not optimal, there is an array conversion to tensor overhead.

# %%
benchmark_2d_mfts(max_pow=13, savefig=False)
